# %%
from socket import *
from _thread import *

client_sockets = [] # 서버에 접속한 클라이언트 목록

# 서버 IP 및 열어줄 포트
HOST = '172.17.12.125'
PORT = 9999

# 서버 소켓 생성
print('>> Server Start')
server_socket = socket(AF_INET, SOCK_STREAM)
server_socket.setsockopt(SOL_SOCKET, SO_REUSEADDR, 1)
server_socket.bind((HOST, PORT))
server_socket.listen()

def threaded(client_socket, addr):
    print('>> Connected by :', addr[0], ':', addr[1])

    # 클라이언트가 접속을 끊을 때 까지 반복합니다.
    while True:

        try:

            # 데이터가 수신되면 클라이언트에 다시 전송합니다.(에코)
            data = client_socket.recv(1024)

            if not data:
                print('>> Disconnected by ' + addr[0], ':', addr[1])
                break

            print('>> Received from ' + addr[0], ':', addr[1], data.decode())

            # 서버에 접속한 클라이언트들에게 채팅 보내기
            # 메세지를 보낸 본인을 제외한 서버에 접속한 클라이언트에게 메세지 보내기
            for client in client_sockets :
                if client != client_socket :
                    client.send(data)

        except ConnectionResetError as e:
            print('>> Disconnected by ' + addr[0], ':', addr[1])
            break
        except UnicodeDecodeError as e:
            pass



    if client_socket in client_sockets :
        client_sockets.remove(client_socket)
        print('remove client list : ',len(client_sockets))

    client_socket.close()

try:
    while True:
        print('>> Wait')

        client_socket, addr = server_socket.accept()
        client_sockets.append(client_socket)
        start_new_thread(threaded, (client_socket, addr))
        print("참가자 수 : ", len(client_sockets))
        
except Exception as e :
    print ('에러는? : ',e)

finally:
    server_socket.close()
# Out:
# >> Server Start
# >> Wait
# 참가자 수 :  1
# >> Wait>> Connected by : 172.17.12.125 :
#  62568
# >> Received from 172.17.12.125 : 62568 ㅇㅇ
# >> Received from 172.17.12.125 : 62568 ㅋㅋ
# >> Received from 172.17.12.125 : 62568 from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:
# >> Received from 172.17.12.125 : 62568     data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")
# >> Received from 172.17.12.125 : 62568    except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':
# >> Received from 172.17.12.125 : 62568 close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client
# >> Received from 172.17.12.125 : 62568 _socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')
# >> Received from 172.17.12.125 : 62568                    except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  wh
# >> Received from 172.17.12.125 : 62568 ile True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thre
# >> Received from 172.17.12.125 : 62568 ad import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1
# >> Received from 172.17.12.125 : 62568 024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:
# >> Received from 172.17.12.125 : 62568 pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         br
# >> Received from 172.17.12.125 : 62568 eak      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))
# >> Received from 172.17.12.125 : 62568 def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except Conne
# >> Received from 172.17.12.125 : 62568 ctionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ',
# >> Received from 172.17.12.125 : 62568 end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.
# >> Received from 172.17.12.125 : 62568 125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nreciv
# >> Received from 172.17.12.125 : 62568 e : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_ne
# >> Received from 172.17.12.125 : 62568 w_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(mes
# >> Received from 172.17.12.125 : 62568 sage.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :
# >> Received from 172.17.12.125 : 62568     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:
# >> Received from 172.17.12.125 : 62568 print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input(
# >> Received from 172.17.12.125 : 62568 '')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket
# >> Received from 172.17.12.125 : 62568  = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))
# >> Received from 172.17.12.125 : 62568         print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_soc
# >> Received from 172.17.12.125 : 62568 ket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.
# >> Received from 172.17.12.125 : 62568 close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:
# >> Received from 172.17.12.125 : 62568            data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")
# >> Received from 172.17.12.125 : 62568           except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':
# >> Received from 172.17.12.125 : 62568        close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)
# >> Received from 172.17.12.125 : 62568  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end =
# >> Received from 172.17.12.125 : 62568 ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Serve
# >> Received from 172.17.12.125 : 62568 r')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * fro
# >> Received from 172.17.12.125 : 62568 m _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket
# >> Received from 172.17.12.125 : 62568 .recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:
# >> Received from 172.17.12.125 : 62568        pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message
# >> Received from 172.17.12.125 : 62568      break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, P
# >> Received from 172.17.12.125 : 62568 ORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      excep
# >> Received from 172.17.12.125 : 62568 t ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Sen
# >> Received from 172.17.12.125 : 62568 d : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172
# >> Received from 172.17.12.125 : 62568 .17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("
# >> Received from 172.17.12.125 : 62568 \nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   s
# >> Received from 172.17.12.125 : 62568 tart_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.s
# >> Received from 172.17.12.125 : 62568 end(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_socket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()from socket import * from _thread import *  HOST = '172.17.12.125' PORT = 9999  client_socket = socket(AF_INET,SOCK_STREAM)  client_socket.connect((HOST, PORT))  def recv_data(client_soc
# >> Received from 172.17.12.125 : 62568 ket) :     while True :         try:             data = client_socket.recv(1024)             print("\nrecive : ",repr(data.decode()))             print('Send : ', end = ' ')                      except ConnectionAbortedError:             print(">> Disconnected Server")          except OSError:             pass                   start_new_thread(recv_data, (client_socket,)) print ('>> Connect Server')  while True:     print('Send : ', end = ' ')     message = input('')     if message == 'quit':         close_data = message         break      client_socket.send(message.encode())   client_socket.close()
# >> Received from 172.17.12.125 : 62568 ㅇㅇ
