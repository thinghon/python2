# %%
from socket import *
from _thread import *

HOST = '172.17.12.125'
PORT = 9999

client_socket = socket(AF_INET,SOCK_STREAM)

client_socket.connect((HOST, PORT))

def recv_data(client_socket) :
    while True :
        try:
            data = client_socket.recv(1024)
            print("\nrecive : ",repr(data.decode()))
            print('Send : ', end = ' ')
            
        except ConnectionAbortedError:
            print(">> Disconnected Server")

        except OSError:
            pass
        
        
start_new_thread(recv_data, (client_socket,))
print ('>> Connect Server')

while True:
    print('Send : ', end = ' ')
    message = input('')
    if message == 'quit':
        close_data = message
        break

    client_socket.send(message.encode())


client_socket.close()
# Out:
# >> Connect Server
# Send :
# recive :  '소호야 너 태열이 닮았엉'
# Send :  ㅈ까
# Send :
# recive :  '장난이얌 ^&^'
# Send :  이거 익명이야
# Send :  ㅋㅋㅋㅋㅋㅋㅋㅋ
# Send :  여러명 들어오면
# Send :  몰라
# Send :  ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# Send :
# recive :  'ㅗ'
# Send :
# recive :  '라고 '
# Send :  난 알수있어
# Send :
# recive :  '영욱이가 보냄'
# Send :  난 서버를 가지고 있거든
# Send :
# recive :  '\t안녕'
# Send :
# recive :  '보여'
# Send :
# recive :  '븅신 ㅋ'
# Send :
# recive :  'ㅗ'
# Send :
# recive :  '섹스'
# Send :
# recive :  'ㅋㅋ'
# Send :
# recive :  'ㅋ'
# Send :
# recive :  'ㅋㅋ'
# Send :
# recive :  'ㅋㅋ'
# Send :
# recive :  'ㅋㅋ'
# Send :
# recive :  'ㅋㅋ'
# Send :
# recive :  '웃지마 ㅋ'
# Send :
# recive :  'ㅋㅋ'
# Send :
# recive :  'ㅋㅋ'
# Send :
# recive :  'ㅋㅋ'
# Send :
# recive :  'ㅋ'
# Send :
# recive :  'ㅋㅋ'
# Send :  김규태
#
# recive :  'ㅋㅋ'
# Send :  Send :
# recive :  'ㅋㅋ'
# Send :
# recive :  'ㅋ'
# Send :  병신
# Send :
# recive :  '발 긔?'
# Send :
# recive :  '?'
# Send :
# recive :  '발 긔?'
# Send :  김규ㅐ 너무 늙음
# Send :
# recive :  '강강민재'
# Send :
# recive :  '개'
# Send :
# recive :  '병'
# Send :
# recive :  '신\\시'
# Send :
# recive :  '발'
# Send :
# recive :  '애'
# Send :
# recive :  '발 기??'
# Send :
# recive :  '새'
# Send :
# recive :  'ㄲ'
# Send :
# recive :  'ㅋㅋ'
# Send :  김규태
# Send :  지팡이 없어??
# Send :
# recive :  '발긔?'
# Send :
# recive :  '19살 ㅋ'
# Send :
# recive :  '19 ㅋ'
# Send :  익명이얌
# Send :
# recive :  '19 ㅋ'
# Send :  ㅋㅋ
# Send :
# recive :  '애새^끼'
# Send :
# recive :  'ㅋㅋ'
# Send :
# recive :  '& C:/Users/admin/AppData/Local/Programs/Python/Python310/python.exe "c:/Users/admin/OneDrive/바탕 화면/PythonWorkspace/Everything.py"'
# Send :
# recive :  '& C:/Users/admin/AppData/Local/Programs/Python/Python310/python.exe "c:/Users/admin/OneDrive/바탕 화면/PythonWorkspace/Everything.py"'
# Send :
# recive :  '안녕'
# Send :  ㅋㅋㅋㅋㅋㅋㅋ
# Send :
# recive :  '& C:/Users/admin/AppData/Local/Programs/Python/Python310/python.exe "c:/Users/admin/OneDrive/바탕 화면/PythonWorkspace/Everything.py"'
# Send :
# recive :  '대답.'
# Send :
# recive :  '인사해'
# Send :
# recive :  '안녕'
# Send :  출튀해야짐
# Send :
# recive :  '안녕'
# Send :
